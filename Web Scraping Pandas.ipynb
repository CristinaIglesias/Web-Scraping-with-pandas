# %%
# Import libraries 

import pandas as pd 
import ssl # SSL: Secure Sockets Layer

ssl._create_default_https_context = ssl._create_unverified_context

#  List of social platforms with at least 100 million active users

data_scraper = pd.read_html("https://en.wikipedia.org/wiki/List_of_social_platforms_with_at_least_100_million_active_users")

data_scraper
# Out:
# [     No.            Name    Company              Country [2]  Launched  \
#  0    1.0        Facebook       Meta            United States      2004
#  1    2.0         YouTube   Alphabet            United States      2005
#  2    3.0        WhatsApp       Meta            United States      2009
#  3    4.0       Messenger       Meta            United States      2011
#  4    5.0       Instagram       Meta            United States      2010
#  5    6.0          WeChat    Tencent                    China      2011
#  6    7.0          TikTok  Bytedance              China[5][6]      2016
#  7    8.0          Douyin  Bytedance                    China      2016
#  8    9.0        Telegram   Telegram  United Arab Emirates[7]      2013
#  9   10.0              QQ    Tencent                    China      1999
#  10  11.0        Snapchat       Snap            United States      2011
#  11  12.0           Weibo       Sina                    China      2009
# ...

# %%
 for index , table in enumerate(data_scraper):
        print(index)
        print(table)
# Out:
# 0
#      No.            Name    Company              Country [2]  Launched  \
# 0    1.0        Facebook       Meta            United States      2004
# 1    2.0         YouTube   Alphabet            United States      2005
# 2    3.0        WhatsApp       Meta            United States      2009
# 3    4.0       Messenger       Meta            United States      2011
# 4    5.0       Instagram       Meta            United States      2010
# 5    6.0          WeChat    Tencent                    China      2011
# 6    7.0          TikTok  Bytedance              China[5][6]      2016
# 7    8.0          Douyin  Bytedance                    China      2016
# 8    9.0        Telegram   Telegram  United Arab Emirates[7]      2013
# 9   10.0              QQ    Tencent                    China      1999
# 10  11.0        Snapchat       Snap            United States      2011
# 11  12.0           Weibo       Sina                    China      2009
# ...

# %%
data_scraper[1]
# Out:
#    No.      Name   Company    Country [3]  Launched  Monthly active users  \
# 0  NaN      Zoom      Zoom  United States      2012                   NaN
# 1  NaN      Meet  Alphabet  United States      2017                   NaN
# 2  NaN  iMessage     Apple  United States      2011                   NaN
# 3  NaN  FaceTime     Apple  United States      2011                   NaN
#
#                           Other metrics
# 0    300 million daily participants[34]
# 1    100 million daily participants[35]
# 2  1.4 billion active Apple devices[36]
# 3  1.4 billion active Apple devices[36]
